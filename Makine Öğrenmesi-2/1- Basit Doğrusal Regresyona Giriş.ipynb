# %% [markdown]
# - Basit = 1 tane bağımsız değişken , 1 tane bağımlı değişkenden oluşan
#
# - Temel amacımız, bağımlı ve bağımsız değişken arasındaki ilişkiyi ifade eden doğrusal fonksiyonu bulmaktır.
#
# - Modellemek, çeşitli kavramlar arasındaki ilişkileri belirli matematiksel formlarda ifade etmek demektir.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) (GERÇEK DEĞERLER)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Buradaki beta0 ve beta1 katsayılarını optimum şekilde nasıl bulabiliriz?
#
# - Bu katsayılar sabit değerler olarak bir denkleme sokulur ve bu denklem aracılığıyla hesaplanmalarını sağlayacak formülasyon elde edilir
#
# - 1. Adım: (y^ yerine b0 + b1.x1 yazdık -> tahmin modelinden)
#
# ![image.png](attachment:image.png)
#
# - 2. Adım:
#
# ![image-2.png](attachment:image-2.png)
#
# - 3. Adım: (tahmin modelini elde ettik)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Geometrik Gösterimi

# %% [markdown]
# ![image.png](attachment:image.png)
