# %% [markdown]
# - İleri beselemede Loss değerleri elde edeceğimizi söylemiştik. Geri beselemeyle ağırlıkları güncelleyerek bu Loss değerini minimize etmeyi amaçlıyoruz.
#
# - Yapay sinir ağlarınada öğrendiğimiz işlemin aynısıdır aslında. Farkı bu işlemin zaman boyutunda yapılacak olmasıdır.
#
# ![image.png](attachment:image.png)
