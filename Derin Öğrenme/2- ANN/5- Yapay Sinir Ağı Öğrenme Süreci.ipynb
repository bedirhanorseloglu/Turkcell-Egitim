# %% [markdown]
# - Süreç nasıl çalışır?
#     - Epoch = iterasyon sayısı
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sinir Ağı Mimarisinin Tasarlanması
#
# - <h3 style="color:red"><b>Hidden Layer'da aktivasyon fonksiyonu olarak neden sigmoid fonksiyonu kullanılıyor da relu fonksiyonu kullanılmıyor?</b></h3>
#     - Nasıl ki insan sinir hücreleri kullanılmadığında ya da gerekli işlevi yerine getiremediğinde ölüyorsa relu fonksiyonu  da yapay sinir ağı açısından bilgi taşımayan, yeterliliği sağlayamayan nöronları söndürme görevi görmektedir.
#
# ![image.png](attachment:image.png)
