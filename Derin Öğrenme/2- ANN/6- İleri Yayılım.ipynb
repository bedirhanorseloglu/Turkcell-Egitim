# %% [markdown]
# Bir önceki bölümde sinir ağımızı tasarlamıştık. Şimdi bu ağ üzerinde ileri yayılım sürecini işleyeceğiz

# %% [markdown]
# - net = giriş
# - out = çıkış
# - Sigmoid aktivasyon fonksiyonunu kullandık
# <br></br>
#
#
# - h1 ve h2 için net ve out değerleri:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# <br></br>
#
#
# - o1 ve o2 (tahmin değerlerimiz) için net ve out değerleri:
#
# ![image.png](attachment:image.png)
# ![image-5.png](attachment:image-5.png)
#
#
# <br></br>
#
#
# - Toplam hata oranımız (MSE):
#
# ![image-6.png](attachment:image-6.png)
