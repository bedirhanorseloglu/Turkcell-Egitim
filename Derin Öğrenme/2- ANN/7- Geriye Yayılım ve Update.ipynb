# %% [markdown]
# Geriye yayılım, sinir ağlarında ağırlık(w) optimizasyonu için kullanılan bir yöntemdir. Amacımız gerçek değerler ile tahmin edilen değerler arasındaki farkı ifade eden error/loss'u minimize etmeye çalışmak. Gradient discent yöntemini kullanarak bu işlemi gerçekleştirir.

# %% [markdown]
# - w5 için geriye yayılım
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# update ettiğimizde (alfa (öğrenme sürecinin hızı. Çok büyük olursa optimum nokta kaçar. Çok küçük olursa süreç uzar) değeri 0.5 olarak verilmiştir.)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# - w1-w2-w3w-w4 için geriye yayılım:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# En sonda oluşan yeni güncel ağırlıklar:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Baştaki hata oranımız 0.2983 iken tek iterasyon ile güncellediğimiz ağırlıklarla bu sayı 0.2910'a düştü
#
# ![image.png](attachment:image.png)
