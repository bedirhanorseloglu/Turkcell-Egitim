# %% [markdown]
# - Elimizdeki veri setinde insanların diyabet olup olmadığına ilişkin veriler var. Amacımız bu 3 birimi (satırı) kullanarak öğrenme işlemini gerçekleştirmek
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Aynı ağırlıklarla işlem yaptığımızda tahminimiz 0 çıktı ama gerçek değerimiz 1 idi. Dolayısıyla ağırlıkları değiştirmemiz gerekmekte.
#
# - İkinci fotoğrafta ağırlıklar değiştiğinde gerçek değer ve tahmini değerimiz uyuştu. Dolayısıyla işimize gelen ağırlık setini kullanacağız. **Peki bu ağırlıkları nasıl, neye göre, kime göre seçeceğiz?** -> **GRADIENT DESCENT (GRADYAN İNİŞ)**
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# İkinci satırın ikincisinde kullandığımız ağırlıkları kullandık ve tahmin ile gerçek değer uyuştu.
#
#
# ![image.png](attachment:image.png)
