# %% [markdown]
# - Bu bölümde adım adım ele aldığımız katmanları genel bir şekilde değerlendireceğiz.
#
# - Aşağıda bir sınıflandırma problemine ait CNN mimarisi verilmiştir:
#     - Girilen görüntünün hangi hayvan olduğunu sınıflandıracaktır.
#
#
#
# ![image-2.png](attachment:image-2.png)
