# %% [markdown]
# - Görüntünün özelliklerini kaybetmeden boyutunun azaltılmasını sağlayan katmandır.
#
# - Bu katmanda herhangi bir öğrenme işlemi yapılMAZ.
#
# - **Peki neden bu işlemi kullanıyoruz?**
#
#     - Hesaplama karmaşıklığını azaltmak, eğtim sürecini azaltmak, daha fazla görsel kullanabilmek için
#
#
# ![image.png](attachment:image.png)
#
#
# <br></br>
#
#
# - Yaygınca kullanılan iki yöntem vardır:
#     - <b style="color:red">Max Pooling</b> -> Gezdirilen filtrelerin maksimumu alındığında
#
#     ![image-3.png](attachment:image-3.png)
#
#
#     - <b style="color:red"> Avarege Pooling</b> -> Gezdirilen filtrelerin ortalamaları alındığında
#
#     (5-3-8-2'nin ortalaması 4 ; 3-1-2-5'in ortalaması 2 ...)
#
#     ![image-2.png](attachment:image-2.png)
#
#
# - Uygulama noktasında hangisini kullanmamız gerektiğine değineceğiz ama hangisini kullandığımızın çok da önemli olmadığını göreceğiz

# %% [markdown]
# # Pooling Katmanından Sonra Görüntüde Ne Oluyor?
#
# - 500x500'lük resmi 250x250'lik bir hale getirdik ve buna rağmen görüntü olmasını istediğimiz gibi daha da keskin bir hal aldı ve aynı zamanda hala aynı öznitelikleri taşır vaziyette.
#
# ![image.png](attachment:image.png)
