# %% [markdown]
# - Bu katmanda, matris formunda olan verimizi flatten işlemiyle yapay sinir ağının algılayabileceği tek boyutlu bir formata getiriyoruz.
#
# - Özetle verinin boyutu tek boyutlu bir diziye indirger.
#
# ![image.png](attachment:image.png)
#
# <br></br>
#
# ![image-2.png](attachment:image-2.png)
#
# <br></br>
#
# ![image-3.png](attachment:image-3.png)
