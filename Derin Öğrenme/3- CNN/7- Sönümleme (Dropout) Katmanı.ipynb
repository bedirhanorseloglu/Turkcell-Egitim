# %% [markdown]
# - Bu katman, modelin aşırı öğrenme sorununu engelleyebilmek adına sinir ağımıza ekleyebileceğimiz bir katmandır.
#
# - Bunu yaparak sinir ağı içerisinde yer alan nöronların kullanıcı tarafından belirlenen bir oranda rastgele olarak söndürülmesiyle aşırı öğrenmeyi önleyerek, performansın artırılması amaçlanmaktadır.
#
# - ANN'de gördüğümüz "9- Yapay Sinir Ağlarında Aşırı Öğrenme.ipynb"deki Dropout işleminin aynısıdır.
#
# ![image.png](attachment:image.png)
