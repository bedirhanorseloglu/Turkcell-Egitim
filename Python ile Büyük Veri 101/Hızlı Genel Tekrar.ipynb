# %%
import findspark
findspark.init("C:\spark")

import pyspark
from pyspark.sql import  SparkSession
from pyspark.conf import SparkConf

# %%
spark = SparkSession.builder.master("local").appName("Psypark Giriş").getOrCreate()

sc = spark.sparkContext

sc
# Out:
# <SparkContext master=local appName=Psypark Giriş>

# %%
spark_df = spark.read.csv("churn.csv" , header=True , inferSchema=True)

# %%
spark_df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Names: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- Total_Purchase: double (nullable = true)
#  |-- Account_Manager: integer (nullable = true)
#  |-- Years: double (nullable = true)
#  |-- Num_Sites: double (nullable = true)
#  |-- Churn: integer (nullable = true)

# %%
spark_df.head()
# Out:
# Row(_c0=0, Names='Cameron Williams', Age=42.0, Total_Purchase=11066.8, Account_Manager=0, Years=7.22, Num_Sites=8.0, Churn=1)

# %%
spark_df.show()
# Out:
# +---+-------------------+----+--------------+---------------+-----+---------+-----+
# |_c0|              Names| Age|Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+-------------------+----+--------------+---------------+-----+---------+-----+
# |  0|   Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|      Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|        Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|      Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|     Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# |  5|   Jessica Williams|48.0|      10356.02|              0| 5.12|      8.0|    1|
# |  6|        Eric Butler|44.0|      11331.58|              1| 5.23|     11.0|    1|
# |  7|      Zachary Walsh|32.0|       9885.12|              1| 6.92|      9.0|    1|
# |  8|        Ashlee Carr|43.0|       14062.6|              1| 5.46|     11.0|    1|
# |  9|     Jennifer Lynch|40.0|       8066.94|              1| 7.11|     11.0|    1|
# | 10|       Paula Harris|30.0|      11575.37|              1| 5.22|      8.0|    1|
# | 11|     Bruce Phillips|45.0|       8771.02|              1| 6.64|     11.0|    1|
# | 12|       Craig Garner|45.0|       8988.67|              1| 4.84|     11.0|    1|
# | 13|       Nicole Olson|40.0|       8283.32|              1|  5.1|     13.0|    1|
# | 14|     Harold Griffin|41.0|       6569.87|              1|  4.3|     11.0|    1|
# | 15|       James Wright|38.0|      10494.82|              1| 6.81|     12.0|    1|
# | 16|      Doris Wilkins|45.0|       8213.41|              1| 7.35|     11.0|    1|
# | 17|Katherine Carpenter|43.0|      11226.88|              0| 8.08|     12.0|    1|
# | 18|     Lindsay Martin|53.0|       5515.09|              0| 6.85|      8.0|    1|
# | 19|        Kathy Curry|46.0|        8046.4|              1| 5.69|      8.0|    1|
# +---+-------------------+----+--------------+---------------+-----+---------+-----+
# only showing top 20 rows

# %%
spark_df.show(8)
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|           Names| Age|Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |  0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# |  5|Jessica Williams|48.0|      10356.02|              0| 5.12|      8.0|    1|
# |  6|     Eric Butler|44.0|      11331.58|              1| 5.23|     11.0|    1|
# |  7|   Zachary Walsh|32.0|       9885.12|              1| 6.92|      9.0|    1|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 8 rows

# %%
spark_df.show(8 , truncate=False)
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|Names           |Age |Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |0  |Cameron Williams|42.0|11066.8       |0              |7.22 |8.0      |1    |
# |1  |Kevin Mueller   |41.0|11916.22      |0              |6.5  |11.0     |1    |
# |2  |Eric Lozano     |38.0|12884.75      |0              |6.67 |12.0     |1    |
# |3  |Phillip White   |42.0|8010.76       |0              |6.71 |10.0     |1    |
# |4  |Cynthia Norton  |37.0|9191.58       |0              |5.56 |9.0      |1    |
# |5  |Jessica Williams|48.0|10356.02      |0              |5.12 |8.0      |1    |
# |6  |Eric Butler     |44.0|11331.58      |1              |5.23 |11.0     |1    |
# |7  |Zachary Walsh   |32.0|9885.12       |1              |6.92 |9.0      |1    |
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 8 rows

# %%
spark_df.count()
# Out:
# 900

# %%
spark_df.describe().show()
# Out:
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |summary|               _c0|        Names|              Age|   Total_Purchase|   Account_Manager|            Years|         Num_Sites|              Churn|
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |  count|               900|          900|              900|              900|               900|              900|               900|                900|
# |   mean|             449.5|         NULL|41.81666666666667|10062.82403333334|0.4811111111111111| 5.27315555555555| 8.587777777777777|0.16666666666666666|
# | stddev|259.95191863111916|         NULL|6.127560416916251|2408.644531858096|0.4999208935073339|1.274449013194616|1.7648355920350969| 0.3728852122772358|
# |    min|                 0|   Aaron King|             22.0|            100.0|                 0|              1.0|               3.0|                  0|
# |    max|               899|Zachary Walsh|             65.0|         18026.01|                 1|             9.15|              14.0|                  1|
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+

# %%
spark_df.describe("Age").show()
# Out:
# +-------+-----------------+
# |summary|              Age|
# +-------+-----------------+
# |  count|              900|
# |   mean|41.81666666666667|
# | stddev|6.127560416916251|
# |    min|             22.0|
# |    max|             65.0|
# +-------+-----------------+

# %%
spark_df.describe("Age" , "Names" , "Total_Purchase").show()
# Out:
# +-------+-----------------+-------------+-----------------+
# |summary|              Age|        Names|   Total_Purchase|
# +-------+-----------------+-------------+-----------------+
# |  count|              900|          900|              900|
# |   mean|41.81666666666667|         NULL|10062.82403333334|
# | stddev|6.127560416916251|         NULL|2408.644531858096|
# |    min|             22.0|   Aaron King|            100.0|
# |    max|             65.0|Zachary Walsh|         18026.01|
# +-------+-----------------+-------------+-----------------+

# %%
spark_df.filter(spark_df.Age > 40).count()
# Out:
# 524

# %%
spark_df.groupBy("Churn").count().show()
# Out:
# +-----+-----+
# |Churn|count|
# +-----+-----+
# |    1|  150|
# |    0|  750|
# +-----+-----+

# %%
spark_df.groupBy("Churn").agg({"Age":"mean"}).show()
# Out:
# +-----+-----------------+
# |Churn|         avg(Age)|
# +-----+-----------------+
# |    1|42.99333333333333|
# |    0|41.58133333333333|
# +-----+-----------------+

# %% [markdown]
# # SQL

# %%
spark_df.createOrReplaceTempView("tbl_df")

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql("show tables").show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |         |   tbl_df|       true|
# +---------+---------+-----------+

# %%
spark.sql("select Age from tbl_df").show()
# Out:
# +----+
# | Age|
# +----+
# |42.0|
# |41.0|
# |38.0|
# |42.0|
# |37.0|
# |48.0|
# |44.0|
# |32.0|
# |43.0|
# |40.0|
# |30.0|
# |45.0|
# |45.0|
# |40.0|
# |41.0|
# |38.0|
# |45.0|
# |43.0|
# |53.0|
# |46.0|
# +----+
# only showing top 20 rows

# %%
spark.sql("select Churn , mean(Age) from tbl_df group by(Churn)").show()
# Out:
# +-----+-----------------+
# |Churn|        mean(Age)|
# +-----+-----------------+
# |    1|42.99333333333333|
# |    0|41.58133333333333|
# +-----+-----------------+

# %% [markdown]
# # Veri Görselleştirme

# %%
import seaborn as sns

# %%
sns.barplot(x="Churn" , y=spark_df.Churn.index , data=spark_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sns.barplot(x="Churn" , y=spark_df.Churn.index , data=spark_df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:532, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     524 # Option 2:
#     525 # We are plotting a long-form dataset
#     526 # -----------------------------------
#    (...)
#     529
#     530     # See if we need to get variables from `data`
#     531     if data is not None:
# --> 532         x = data.get(x, x)
#     533         y = data.get(y, y)
#     534         hue = data.get(hue, hue)
#
# File C:\spark\python\pyspark\sql\dataframe.py:3129, in DataFrame.__getattr__(self, name)
#    3096 """Returns the :class:`Column` denoted by ``name``.
#    3097
#    3098 .. versionadded:: 1.3.0
#    (...)
#    3126 +---+
#    3127 """
#    3128 if name not in self.columns:
# -> 3129     raise AttributeError(
#    3130         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    3131     )
#    3132 jc = self._jdf.apply(name)
#    3133 return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'get'

# %%
sdf = spark_df.toPandas()

sdf.head()
# Out:
#    _c0             Names   Age  Total_Purchase  Account_Manager  Years
# 0    0  Cameron Williams  42.0        11066.80                0   7.22  \
# 1    1     Kevin Mueller  41.0        11916.22                0   6.50
# 2    2       Eric Lozano  38.0        12884.75                0   6.67
# 3    3     Phillip White  42.0         8010.76                0   6.71
# 4    4    Cynthia Norton  37.0         9191.58                0   5.56
#
#    Num_Sites  Churn
# 0        8.0      1
# 1       11.0      1
# 2       12.0      1
# 3       10.0      1
# 4        9.0      1

# %%
sns.barplot(x="Churn" , y=sdf.Churn.index , data=sdf)
# Out:
# <Axes: xlabel='Churn'>

# %% [markdown]
# # Makine Öğrenmesi Kısmı

# %%
spark_df = spark_df.toDF(*[c.lower() for c in spark_df.columns])

spark_df.show()
# Out:
# +---+-------------------+----+--------------+---------------+-----+---------+-----+
# |_c0|              names| age|total_purchase|account_manager|years|num_sites|churn|
# +---+-------------------+----+--------------+---------------+-----+---------+-----+
# |  0|   Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|      Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|        Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|      Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|     Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# |  5|   Jessica Williams|48.0|      10356.02|              0| 5.12|      8.0|    1|
# |  6|        Eric Butler|44.0|      11331.58|              1| 5.23|     11.0|    1|
# |  7|      Zachary Walsh|32.0|       9885.12|              1| 6.92|      9.0|    1|
# |  8|        Ashlee Carr|43.0|       14062.6|              1| 5.46|     11.0|    1|
# |  9|     Jennifer Lynch|40.0|       8066.94|              1| 7.11|     11.0|    1|
# | 10|       Paula Harris|30.0|      11575.37|              1| 5.22|      8.0|    1|
# | 11|     Bruce Phillips|45.0|       8771.02|              1| 6.64|     11.0|    1|
# | 12|       Craig Garner|45.0|       8988.67|              1| 4.84|     11.0|    1|
# | 13|       Nicole Olson|40.0|       8283.32|              1|  5.1|     13.0|    1|
# | 14|     Harold Griffin|41.0|       6569.87|              1|  4.3|     11.0|    1|
# | 15|       James Wright|38.0|      10494.82|              1| 6.81|     12.0|    1|
# | 16|      Doris Wilkins|45.0|       8213.41|              1| 7.35|     11.0|    1|
# | 17|Katherine Carpenter|43.0|      11226.88|              0| 8.08|     12.0|    1|
# | 18|     Lindsay Martin|53.0|       5515.09|              0| 6.85|      8.0|    1|
# | 19|        Kathy Curry|46.0|        8046.4|              1| 5.69|      8.0|    1|
# +---+-------------------+----+--------------+---------------+-----+---------+-----+
# only showing top 20 rows

# %%
spark_df = spark_df.withColumnRenamed("_c0" , "index")

spark_df.show()
# Out:
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+
# |index|              names| age|total_purchase|account_manager|years|num_sites|churn|
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+
# |    0|   Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |    1|      Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |    2|        Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |    3|      Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |    4|     Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# |    5|   Jessica Williams|48.0|      10356.02|              0| 5.12|      8.0|    1|
# |    6|        Eric Butler|44.0|      11331.58|              1| 5.23|     11.0|    1|
# |    7|      Zachary Walsh|32.0|       9885.12|              1| 6.92|      9.0|    1|
# |    8|        Ashlee Carr|43.0|       14062.6|              1| 5.46|     11.0|    1|
# |    9|     Jennifer Lynch|40.0|       8066.94|              1| 7.11|     11.0|    1|
# |   10|       Paula Harris|30.0|      11575.37|              1| 5.22|      8.0|    1|
# |   11|     Bruce Phillips|45.0|       8771.02|              1| 6.64|     11.0|    1|
# |   12|       Craig Garner|45.0|       8988.67|              1| 4.84|     11.0|    1|
# |   13|       Nicole Olson|40.0|       8283.32|              1|  5.1|     13.0|    1|
# |   14|     Harold Griffin|41.0|       6569.87|              1|  4.3|     11.0|    1|
# |   15|       James Wright|38.0|      10494.82|              1| 6.81|     12.0|    1|
# |   16|      Doris Wilkins|45.0|       8213.41|              1| 7.35|     11.0|    1|
# |   17|Katherine Carpenter|43.0|      11226.88|              0| 8.08|     12.0|    1|
# |   18|     Lindsay Martin|53.0|       5515.09|              0| 6.85|      8.0|    1|
# |   19|        Kathy Curry|46.0|        8046.4|              1| 5.69|      8.0|    1|
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+
# only showing top 20 rows

# %% [markdown]
# # Büyük Veride Ön İşleme

# %%
spark_df.dropna()
# Out:
# DataFrame[index: int, names: string, age: double, total_purchase: double, account_manager: int, years: double, num_sites: double, churn: int]

# %%
spark_df = spark_df.withColumn("age_kare" , spark_df.age**2)
spark_df.show()
# Out:
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+
# |index|              names| age|total_purchase|account_manager|years|num_sites|churn|age_kare|
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+
# |    0|   Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|  1764.0|
# |    1|      Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|  1681.0|
# |    2|        Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|  1444.0|
# |    3|      Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|  1764.0|
# |    4|     Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|  1369.0|
# |    5|   Jessica Williams|48.0|      10356.02|              0| 5.12|      8.0|    1|  2304.0|
# |    6|        Eric Butler|44.0|      11331.58|              1| 5.23|     11.0|    1|  1936.0|
# |    7|      Zachary Walsh|32.0|       9885.12|              1| 6.92|      9.0|    1|  1024.0|
# |    8|        Ashlee Carr|43.0|       14062.6|              1| 5.46|     11.0|    1|  1849.0|
# |    9|     Jennifer Lynch|40.0|       8066.94|              1| 7.11|     11.0|    1|  1600.0|
# |   10|       Paula Harris|30.0|      11575.37|              1| 5.22|      8.0|    1|   900.0|
# |   11|     Bruce Phillips|45.0|       8771.02|              1| 6.64|     11.0|    1|  2025.0|
# |   12|       Craig Garner|45.0|       8988.67|              1| 4.84|     11.0|    1|  2025.0|
# |   13|       Nicole Olson|40.0|       8283.32|              1|  5.1|     13.0|    1|  1600.0|
# |   14|     Harold Griffin|41.0|       6569.87|              1|  4.3|     11.0|    1|  1681.0|
# |   15|       James Wright|38.0|      10494.82|              1| 6.81|     12.0|    1|  1444.0|
# |   16|      Doris Wilkins|45.0|       8213.41|              1| 7.35|     11.0|    1|  2025.0|
# |   17|Katherine Carpenter|43.0|      11226.88|              0| 8.08|     12.0|    1|  1849.0|
# |   18|     Lindsay Martin|53.0|       5515.09|              0| 6.85|      8.0|    1|  2809.0|
# |   19|        Kathy Curry|46.0|        8046.4|              1| 5.69|      8.0|    1|  2116.0|
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StringIndexer

stringIndexer = StringIndexer(inputCol="churn" , outputCol="label")

mod = stringIndexer.fit(spark_df)

indexed = mod.transform(spark_df)

spark_df = indexed.withColumn("label"  , indexed["label"].cast("integer"))

spark_df.show()
# Out:
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+-----+
# |index|              names| age|total_purchase|account_manager|years|num_sites|churn|age_kare|label|
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+-----+
# |    0|   Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|  1764.0|    1|
# |    1|      Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|  1681.0|    1|
# |    2|        Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|  1444.0|    1|
# |    3|      Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|  1764.0|    1|
# |    4|     Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|  1369.0|    1|
# |    5|   Jessica Williams|48.0|      10356.02|              0| 5.12|      8.0|    1|  2304.0|    1|
# |    6|        Eric Butler|44.0|      11331.58|              1| 5.23|     11.0|    1|  1936.0|    1|
# |    7|      Zachary Walsh|32.0|       9885.12|              1| 6.92|      9.0|    1|  1024.0|    1|
# |    8|        Ashlee Carr|43.0|       14062.6|              1| 5.46|     11.0|    1|  1849.0|    1|
# |    9|     Jennifer Lynch|40.0|       8066.94|              1| 7.11|     11.0|    1|  1600.0|    1|
# |   10|       Paula Harris|30.0|      11575.37|              1| 5.22|      8.0|    1|   900.0|    1|
# |   11|     Bruce Phillips|45.0|       8771.02|              1| 6.64|     11.0|    1|  2025.0|    1|
# |   12|       Craig Garner|45.0|       8988.67|              1| 4.84|     11.0|    1|  2025.0|    1|
# |   13|       Nicole Olson|40.0|       8283.32|              1|  5.1|     13.0|    1|  1600.0|    1|
# |   14|     Harold Griffin|41.0|       6569.87|              1|  4.3|     11.0|    1|  1681.0|    1|
# |   15|       James Wright|38.0|      10494.82|              1| 6.81|     12.0|    1|  1444.0|    1|
# |   16|      Doris Wilkins|45.0|       8213.41|              1| 7.35|     11.0|    1|  2025.0|    1|
# |   17|Katherine Carpenter|43.0|      11226.88|              0| 8.08|     12.0|    1|  1849.0|    1|
# |   18|     Lindsay Martin|53.0|       5515.09|              0| 6.85|      8.0|    1|  2809.0|    1|
# |   19|        Kathy Curry|46.0|        8046.4|              1| 5.69|      8.0|    1|  2116.0|    1|
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+-----+
# only showing top 20 rows

# %%
from pyspark.ml.feature import VectorAssembler

bagımsız_degiskenler = ["age" , "total_purchase" , "account_manager" , "years" , "years"]

vectorAssembler = VectorAssembler(inputCols = bagımsız_degiskenler , outputCol="features")

va_df = vectorAssembler.transform(spark_df)

va_df.show(truncate=False)
# Out:
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+-----+-----------------------------+
# |index|names              |age |total_purchase|account_manager|years|num_sites|churn|age_kare|label|features                     |
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+-----+-----------------------------+
# |0    |Cameron Williams   |42.0|11066.8       |0              |7.22 |8.0      |1    |1764.0  |1    |[42.0,11066.8,0.0,7.22,7.22] |
# |1    |Kevin Mueller      |41.0|11916.22      |0              |6.5  |11.0     |1    |1681.0  |1    |[41.0,11916.22,0.0,6.5,6.5]  |
# |2    |Eric Lozano        |38.0|12884.75      |0              |6.67 |12.0     |1    |1444.0  |1    |[38.0,12884.75,0.0,6.67,6.67]|
# |3    |Phillip White      |42.0|8010.76       |0              |6.71 |10.0     |1    |1764.0  |1    |[42.0,8010.76,0.0,6.71,6.71] |
# |4    |Cynthia Norton     |37.0|9191.58       |0              |5.56 |9.0      |1    |1369.0  |1    |[37.0,9191.58,0.0,5.56,5.56] |
# |5    |Jessica Williams   |48.0|10356.02      |0              |5.12 |8.0      |1    |2304.0  |1    |[48.0,10356.02,0.0,5.12,5.12]|
# |6    |Eric Butler        |44.0|11331.58      |1              |5.23 |11.0     |1    |1936.0  |1    |[44.0,11331.58,1.0,5.23,5.23]|
# |7    |Zachary Walsh      |32.0|9885.12       |1              |6.92 |9.0      |1    |1024.0  |1    |[32.0,9885.12,1.0,6.92,6.92] |
# |8    |Ashlee Carr        |43.0|14062.6       |1              |5.46 |11.0     |1    |1849.0  |1    |[43.0,14062.6,1.0,5.46,5.46] |
# |9    |Jennifer Lynch     |40.0|8066.94       |1              |7.11 |11.0     |1    |1600.0  |1    |[40.0,8066.94,1.0,7.11,7.11] |
# |10   |Paula Harris       |30.0|11575.37      |1              |5.22 |8.0      |1    |900.0   |1    |[30.0,11575.37,1.0,5.22,5.22]|
# |11   |Bruce Phillips     |45.0|8771.02       |1              |6.64 |11.0     |1    |2025.0  |1    |[45.0,8771.02,1.0,6.64,6.64] |
# |12   |Craig Garner       |45.0|8988.67       |1              |4.84 |11.0     |1    |2025.0  |1    |[45.0,8988.67,1.0,4.84,4.84] |
# |13   |Nicole Olson       |40.0|8283.32       |1              |5.1  |13.0     |1    |1600.0  |1    |[40.0,8283.32,1.0,5.1,5.1]   |
# |14   |Harold Griffin     |41.0|6569.87       |1              |4.3  |11.0     |1    |1681.0  |1    |[41.0,6569.87,1.0,4.3,4.3]   |
# |15   |James Wright       |38.0|10494.82      |1              |6.81 |12.0     |1    |1444.0  |1    |[38.0,10494.82,1.0,6.81,6.81]|
# |16   |Doris Wilkins      |45.0|8213.41       |1              |7.35 |11.0     |1    |2025.0  |1    |[45.0,8213.41,1.0,7.35,7.35] |
# |17   |Katherine Carpenter|43.0|11226.88      |0              |8.08 |12.0     |1    |1849.0  |1    |[43.0,11226.88,0.0,8.08,8.08]|
# |18   |Lindsay Martin     |53.0|5515.09       |0              |6.85 |8.0      |1    |2809.0  |1    |[53.0,5515.09,0.0,6.85,6.85] |
# |19   |Kathy Curry        |46.0|8046.4        |1              |5.69 |8.0      |1    |2116.0  |1    |[46.0,8046.4,1.0,5.69,5.69]  |
# +-----+-------------------+----+--------------+---------------+-----+---------+-----+--------+-----+-----------------------------+
# only showing top 20 rows

# %%
final_df = va_df.select(["features" , "label"])

final_df.show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[42.0,11066.8,0.0...|    1|
# |[41.0,11916.22,0....|    1|
# |[38.0,12884.75,0....|    1|
# |[42.0,8010.76,0.0...|    1|
# |[37.0,9191.58,0.0...|    1|
# |[48.0,10356.02,0....|    1|
# |[44.0,11331.58,1....|    1|
# |[32.0,9885.12,1.0...|    1|
# |[43.0,14062.6,1.0...|    1|
# |[40.0,8066.94,1.0...|    1|
# |[30.0,11575.37,1....|    1|
# |[45.0,8771.02,1.0...|    1|
# |[45.0,8988.67,1.0...|    1|
# |[40.0,8283.32,1.0...|    1|
# |[41.0,6569.87,1.0...|    1|
# |[38.0,10494.82,1....|    1|
# |[45.0,8213.41,1.0...|    1|
# |[43.0,11226.88,0....|    1|
# |[53.0,5515.09,0.0...|    1|
# |[46.0,8046.4,1.0,...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %%
splits = final_df.randomSplit([0.70  , 0.30])

train_df = splits[0]
test_df = splits[1]

# %% [markdown]
# # Modelleme

# %%
import pyspark
from pyspark.ml.classification import GBTClassifier #GBM algoritması

# %%
gbm_model = GBTClassifier(maxIter=10 , featuresCol="features" , labelCol="label").fit(train_df)

# %%
y_pred = gbm_model.transform(test_df)
y_pred
# Out:
# DataFrame[features: vector, label: int, rawPrediction: vector, probability: vector, prediction: double]

# %%
ac = y_pred.select("label" , "prediction")

ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8175895765472313
