# %% [markdown]
# # Büyük Veri Nedir

# %% [markdown]
# - Geleneksel yöntemlerle işlenemeyen verilere büyük veri denir. Geleneksel yöntemlerle işlenememe durumu bazen verinin boyutu, bazen verinin türü ve bazen de verinin hızlı bir şekilde değişebiliyor olmasıdır.
# - Bu problemin çözümü birden fazla bilgisayarın bir araya getirilerek tek bir bilgisayar gibi hareket etmesidir. Yani bir işi yapmak için birden fazla bilgisayarın tek bir bilgisayar gibi davranmasıdır.
# - Bu problemin çözülmesi veri analitiği alanında yeni ufuklar açtı, hesaplama gücünün artmasıyla makine öğrenmesi algoritmalarının performansları arttı. Daha büyük miktar ve çeşitteki verilerin kullanılması ile veriden faydalı bilgi çıkarma süreci için çok önemli bir kaynak sağlanmış oldu.

# %% [markdown]
# # Büyük Verinin Bileşenleri

# %% [markdown]
# - Ortaya çıkan veri işleme güçlüğü verinin hacmi(volume) , çeşitliliği(variety) ve hızı(velocity ) ile alakalıdır.
#
# ![image.png](attachment:image.png)
#
#
# - Büyük veriyi ifade eden özellikler hacim, çeşitlilik ve hızdır.
# - Çok yaygın bir yanılgı ise bu özelliklerin ancak birlikte olduğunda veriye büyük veri denilebileceğidir. (Örneğin elimizdeki verinin hacmi çok çok büyüktür ancak gerçek zamanlı eşlenmesine gerek yoktur. Bu durumda elimizdeki veriye büyük veri değildir diyemeyiz. Ana odağımızda hacim olmalıdır.)
# - Büyük veri araçları veriden faydalı bilgi çıkarma süreçleri için çok güçlü bir araçtır.
