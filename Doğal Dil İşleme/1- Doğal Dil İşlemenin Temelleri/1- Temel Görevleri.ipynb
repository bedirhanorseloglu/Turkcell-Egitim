# %% [markdown]
# 1- Metin sınıflandırma
#
# 2- Duygu analizi
#
# 3- Adlandırılmış varlık tanıma
#
# ![image.png](attachment:image.png)
#
# 4- Part of Speech (POS) Etiketleme
#
# ![image-2.png](attachment:image-2.png)
#
# 5- Metin özetleme
#
# 6- Dil çevirisi
#
# 7- Chatbot
#
# 8- Konuşma tanıma (Text to Speech - Speech to Text)
