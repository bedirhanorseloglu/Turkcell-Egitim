# %% [markdown]
# - Bag of Words, doğal dil işleme (NLP) ve metin madenciliğinde kullanılan temel bir metin temsili yöntemidir.
# - BoW, metinlerdeki kelimeleri sayısal verilere dönüştürür ve metinlerin analizini sağlar
#
# ![image.png](attachment:image.png)
#
# - BoW'un işleyişi (CountVectorizer()):
#     - Kelime kümesi oluşturma (get_feature_names_out())
#     - Kelime frekanslarını hesaplama
#     - Vektör temsili
#
#     ![image-2.png](attachment:image-2.png)
