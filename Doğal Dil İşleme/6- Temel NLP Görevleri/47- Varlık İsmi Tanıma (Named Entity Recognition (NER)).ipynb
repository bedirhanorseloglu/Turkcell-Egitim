# %% [markdown]
# - Named Entity Recognitation(NER); metin içerisindeki kişi, yer, organizasyon gibi özel isimleri tanımlayarak yapılandırılmamış veriden anlamlı bilgiler çıkarmayı sağlar.
#
# - Kullanım Alanları:
#     - Bilgi çıkarımı
#     - Otomatik özetleme
#     - Müşteri ilişkileri -> mesela müşteri veri tabanlarında kişi şirket isimlerini otomatik tespit ve analizi
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
