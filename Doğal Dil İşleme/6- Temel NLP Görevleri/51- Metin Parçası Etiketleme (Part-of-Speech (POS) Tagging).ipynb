# %% [markdown]
# - Bir metin içerisindeki her bir kelimenin dilbilgisel kategorsini belirleyerek cümlelerin dil yapısını analiz etmeyi sağlar.
#
# - Kullanım Alanları:
#     - Doğal dil işleme
#     - Makine çevirisi
#     - Sözcük türü analizi
#
# ![image.png](attachment:image.png)
