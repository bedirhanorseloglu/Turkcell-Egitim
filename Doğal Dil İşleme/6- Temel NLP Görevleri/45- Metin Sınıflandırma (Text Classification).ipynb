# %% [markdown]
# - Metin sınıflandırma, metinleri otomatik olarak belirli kategorilere ayrılmasını sağlar
#
# ![image.png](attachment:image.png)
#
# - Kullanım Alanları:
#     - E-posta filtreleme
#     - Döküman yönetimi
#     - Sosyal medya izleme
