# %%
# Kütüphaneler

import pandas as pd
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt



from warnings import filterwarnings
filterwarnings("ignore")     # önceki bölümlerde çalıştırdığımızda çıkan gereksiz uyarı mesajları çıkmasın diye
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Kütüphaneler
#       3 import pandas as pd
# ----> 4 from sklearn.model_selection import train_test_split , GridSearchCV
#       5 from sklearn.metrics import accuracy_score
#       6 import matplotlib.pyplot as plt
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\__init__.py:83
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#    (...)     77     # later is linked to the OpenMP runtime to make it possible to introspect
#      78     # it and importing it first would fail if the OpenMP dll cannot be found.
#      79     from . import (
#      80         __check_build,  # noqa: F401
#      81         _distributor_init,  # noqa: F401
#      82     )
# ---> 83     from .base import clone
#      84     from .utils._show_versions import show_versions
#      86     __all__ = [
#      87         "calibration",
#      88         "cluster",
#    (...)    129         "show_versions",
#     130     ]
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\utils\__init__.py:22
#      20 from ._bunch import Bunch
#      21 from ._estimator_html_repr import estimator_html_repr
# ---> 22 from ._param_validation import Interval, validate_params
#      23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from .deprecation import deprecated
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:15
#      12 from scipy.sparse import csr_matrix, issparse
#      14 from .._config import config_context, get_config
# ---> 15 from .validation import _is_arraylike_not_scalar
#      18 class InvalidParameterError(ValueError, TypeError):
#      19     """Custom exception to be raised when the parameter of a class/method/function
#      20     does not have a valid type or value.
#      21     """
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\utils\validation.py:25
#      23 from .. import get_config as _get_config
#      24 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 25 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      26 from ..utils.fixes import ComplexWarning
#      27 from ._isfinite import FiniteStatus, cy_isfinite
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:9
#       6 import scipy.special as special
#       8 from .._config import get_config
# ----> 9 from .fixes import parse_version
#      12 def _check_array_api_dispatch(array_api_dispatch):
#      13     """Check that array_api_compat is installed and NumPy version is compatible.
#      14
#      15     array_api_compat follows NEP29, which has a higher minimum NumPy version than
#      16     scikit-learn.
#      17     """
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\sklearn\utils\fixes.py:19
#      17 import scipy
#      18 import scipy.sparse.linalg
# ---> 19 import scipy.stats
#      20 import threadpoolctl
#      22 import sklearn
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\scipy\stats\__init__.py:608
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    603
#     604 """
#     606 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     607                                DegenerateDataWarning, FitError)
# --> 608 from ._stats_py import *
#     609 from ._variation import variation
#     610 from .distributions import *
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:37
#      35 from numpy import array, asarray, ma
#      36 from numpy.lib import NumpyVersion
# ---> 37 from numpy.testing import suppress_warnings
#      39 from scipy.spatial.distance import cdist
#      40 from scipy.ndimage import _measurements
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\site-packages\numpy\testing\__init__.py:8
#       1 """Common test support for all numpy test scripts.
#       2
#       3 This single module should provide all the common functionality for numpy tests
#    (...)      6
#       7 """
# ----> 8 from unittest import TestCase
#      10 from . import _private
#      11 from ._private.utils import *
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\unittest\__init__.py:61
#      58 __unittest = True
#      60 from .result import TestResult
# ---> 61 from .case import (addModuleCleanup, TestCase, FunctionTestCase, SkipTest, skip,
#      62                    skipIf, skipUnless, expectedFailure, doModuleCleanups,
#      63                    enterModuleContext)
#      64 from .suite import BaseTestSuite, TestSuite
#      65 from .loader import TestLoader, defaultTestLoader
#
# File c:\Users\BedirhanOrseloglu\anaconda3\Lib\unittest\case.py:5
#       3 import sys
#       4 import functools
# ----> 5 import difflib
#       6 import pprint
#       7 import re
#
# ModuleNotFoundError: No module named 'difflib'

# %%
df = pd.read_csv("Veri ve Fotoğraflar\diabetes.csv")
df.head()


# Bağımlı değişkenimiz "Outcome". Yani burada kişi diyabet hastası mı değil mi bunu inceliyoruz. 1, hasta ; 0, hasta değil
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df["Outcome"]

x = df.drop(["Outcome"] , axis=1)

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.30 , random_state=42)

# %%
# MODELLER

modeller = [knn_tuned , loj_tuned , svm_tuned , mlpc_tuned , cart_tuned , cart_tuned , gbm_tuned , rf_tuned , catboost_tuned , lgbm_tuned , xgb_tuned]

sonuc = []

sonuclar = pd.DataFrame(columns=["Modeller" , "Accuracy"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # MODELLER
# ----> 3 modeller = [knn_tuned , loj_tuned , svm_tuned , mlpc_tuned , cart_tuned , cart_tuned , gbm_tuned , rf_tuned , catboost_tuned , lgbm_tuned , xgb_tuned]
#       5 sonuc = []
#       7 sonuclar = pd.DataFrame(columns=["Modeller" , "Accuracy"])
#
# NameError: name 'knn_tuned' is not defined

# %%
for model in modeller:
    isimler = model.__class__.__name__
    y_pred = model.predict(x_test)
    doğruluk = accuracy_score(y_test, y_pred)
    sonuc = pd.DataFrame([[isimler, doğruluk * 100]], columns=["Modeller", "Accuracy"])
    sonuclar = pd.concat([sonuclar, sonuc], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for model in modeller:
#       2     isimler = model.__clas__.__name__
#       3     y_pred = model.predict(x_test)
#
# NameError: name 'modeller' is not defined

# %%
sns_barplot = (x= 'Accuracy' , y= 'Modeller' , data=sonuclar , color='r')
plt.xlabel("Accuracy %")
plt.ylabel("Modellerin Doğruluk Oranları")
plt.show()

# %%
sonuclar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sonuclar
#
# NameError: name 'sonuclar' is not defined
