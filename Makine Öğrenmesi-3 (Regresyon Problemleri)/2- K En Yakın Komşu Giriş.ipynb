# %% [markdown]
# Gözlemlerin birbirine olan benzerlikleri üzerinden tahmin yapılır.
#
# Sınıflandırma ya da regresyon problemlerinde kullanılabilen algoritmadır.
#
# Parametrik olmayan bir öğrenme türüdür.
#
# Özellikle büyük veri setlerinde performans olarak çok iyi olduğu söylenemez ancak basit olması, kolayca uygulanabilir olması yönünden sıkça kullanılan algoritmalardan birisidir.

# %% [markdown]
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# # KNN'nin Basamakları
#     - Komşu sayısını belirle (K)
#     - Bilinmeyen noktanın diğer tüm noktalar ile arasındaki uzaklıkları hesapla
#     - Uzaklıkları sırala ve belirlenen K sayısına göre en yakın K tane gözlemi seç
#     - Sınıflandırma ise en sık sınıf, regresyon ise ortalama değeri tahmin değeri olarak ver
